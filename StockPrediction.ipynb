# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Gathering Data
#Data preparation
#Data Wrangling
#Analyse Data
#Train the model
#Test the model
#Deployment


# 0 Preprocessing + EDA + Features selection
# 1 Extract input and output col
# 2 Scale the value
# 3 Train test splite 
# 4 Train the model
# 5 Evalute the model / Model Selection
# 6 Deploy the model

# %%
# 0 Preprocessing + EDA + Features selection
Df=pd.read_csv('bnfdata.csv')
Df


Df['Average_Price'] = (Df['high'] + Df['low']) / 2
Df['PriceChange']=Df['open']-Df['close']
Df['Next_Close'] = Df['close'].shift(-1)
Df['NewClose']=Df['close']-Df['open'].shift(-1)

# %%
#0.1 Preprocessinig 
#Df.isnull().sum()
#Df.dropna(axis=1)
Df
# Out:
#       Unnamed: 0                       date      open      high       low  \
# 0              0  2015-01-01 09:15:00+05:30  18728.20  18781.55  18638.84
# 1              1  2015-01-02 09:15:00+05:30  18752.20  19118.84  18752.20
# 2              2  2015-01-05 09:15:00+05:30  19155.20  19166.00  18987.70
# 3              3  2015-01-06 09:15:00+05:30  18874.59  18874.59  18388.34
# 4              4  2015-01-07 09:15:00+05:30  18382.55  18482.05  18211.50
# ...          ...                        ...       ...       ...       ...
# 2473        2473  2024-10-21 00:00:00+05:30  52361.10  52577.50  51855.15
# 2474        2474  2024-10-22 00:00:00+05:30  52071.35  52257.30  51179.60
# 2475        2475  2024-10-23 00:00:00+05:30  51117.80  51551.55  51107.90
# 2476        2476  2024-10-24 00:00:00+05:30  51272.30  51781.55  51201.85
# 2477        2477  2024-10-25 00:00:00+05:30  51369.75  51501.05  50382.10
#
#          close  volume      symbol  Average_Price  PriceChange  Next_Close  \
# ...

# %%
# 0.2 EDA 
plt.plot(Df['close'])

# %%
# 0.2 EDA 
# plt.plot(Df['open'])

# %%
# 0.3 FS 
Df.drop(['symbol','volume'], axis=1, inplace=True)
# df.drop('column_name', axis=1, inplace=True

# %%
# 0.3 Fs
Df = Df.iloc[:, 1:]
Df
# Out:
#                            date      open      high       low     close  \
# 0     2015-01-01 09:15:00+05:30  18728.20  18781.55  18638.84  18750.45
# 1     2015-01-02 09:15:00+05:30  18752.20  19118.84  18752.20  19057.80
# 2     2015-01-05 09:15:00+05:30  19155.20  19166.00  18987.70  19017.40
# 3     2015-01-06 09:15:00+05:30  18874.59  18874.59  18388.34  18430.75
# 4     2015-01-07 09:15:00+05:30  18382.55  18482.05  18211.50  18304.25
# ...                         ...       ...       ...       ...       ...
# 2473  2024-10-21 00:00:00+05:30  52361.10  52577.50  51855.15  51962.70
# 2474  2024-10-22 00:00:00+05:30  52071.35  52257.30  51179.60  51257.15
# 2475  2024-10-23 00:00:00+05:30  51117.80  51551.55  51107.90  51239.00
# 2476  2024-10-24 00:00:00+05:30  51272.30  51781.55  51201.85  51531.15
# 2477  2024-10-25 00:00:00+05:30  51369.75  51501.05  50382.10  50854.70
#
#       Average_Price  PriceChange  Next_Close  NewClose
# ...

# %%
# 1 Extract input and output col
# 2 Scale the value

# %%
# 3 Train test splite 

from sklearn.model_selection import train_test_split
X=Df[['open','high','low','close','Average_Price','PriceChange','Next_Close']]
# Target
Y=Df['Next_Close']

X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=0.1)

# %%
# Scaling the values
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
# training the model
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 5
#       2 from sklearn.linear_model import LinearRegression
#       4 LR=LinearRegression()
# ----> 5 LR.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...

# %%
# 5 Evalute the model / Model Selection      _>>>>> Check the accurcy with test data 

LR.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[98], line 3
#       1 # 5 Evalute the model / Model Selection      _>>>>> Check the accurcy with test data
# ----> 3 LR.predict(X_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:335, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
# --> 335     check_is_fitted(self)
#     337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...
